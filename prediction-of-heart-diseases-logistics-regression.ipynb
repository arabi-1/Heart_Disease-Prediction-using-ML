# %% [markdown]
# ![Data Seekho Google Form Background (3).png](data:image/png;base64,...)

# %% [markdown]
# # Hi, I'm Muhammad Arabi 👋
#
# Welcome to my GitHub profile! I'm currently a **Machine Learning Bootcamp Fellow** at [Data Seekho](https://dataseekho.com), where I'm honing my expertise in machine learning, data science, and artificial intelligence. I am driven by a passion for solving real-world challenges through data-driven solutions and am committed to deepening my knowledge and skills in this dynamic field.
#
#
# ---
#
# ## 🌟 About Me
# - 🎓 **Education**: Bachelor’s in Software Engineering from COMSATS University Islambad
# - 💻 **Skills**: Python, SQL, Machine Learning, Data Visualization, Pandas, NumPy, Scikit-Learn, TensorFlow, Matplotlib, Seaborn
# - 🌱 **Currently Learning**: Python, Data Analytics, and Advanced Data Science techniques
# - 🤝 **Looking to collaborate on**: Open-source data science projects and machine learning competitions
# - 🔭 **Research Interests**: Data Science, AI Ethics, Predictive Modeling, Generative AI
# - 📫 **How to reach me**: khanarabi80@gmail.com | www.linkedin.com/in/mohammad-arabi-b62493238

# %% [markdown]
# # Import Required Libraries

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Load and Explore Data

# %%
df =pd.read_csv("/kaggle/input/prediction-of-heart-disease-by-logistic-regression/heart dataset.csv")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
df["sex"].unique()
# Out:
# array([1, 0])

# %%
# Set up styles for the plots
sns.set(style="whitegrid")

# %% [markdown]
# # Age Distribution by Target

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x="age", hue="target", multiple="stack", kde=True)
plt.title("Age Distribution by Target")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
df.shape
# Out:
# (303, 14)

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %% [markdown]
# # Count Plot of Sex vs Target

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='sex', hue='target', data=df)
plt.title("Count of Sex vs Target")
plt.xlabel("Sex (0 = Female, 1 = Male)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Box Plot of Age by Target

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='target', y='age', data=df)
plt.title("Age Distribution by Target")
plt.xlabel("Target")
plt.ylabel("Age")
plt.show()

# %% [markdown]
# # Heatmap of Correlation

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# # Cholesterol Levels by Target

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x="chol", hue="target", kde=True, bins=15)
plt.title("Cholesterol Levels by Target")
plt.xlabel("Cholesterol")
plt.ylabel("Frequency")
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# # Scatter Plot of Age vs Cholesterol by Target

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='chol', hue='target', data=df)
plt.title("Scatter Plot of Age vs Cholesterol by Target")
plt.xlabel("Age")
plt.ylabel("Cholesterol")
plt.show()

# %% [markdown]
# # Box Plot of Cholesterol by Chest Pain Type (cp)

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='cp', y='chol', hue='target', data=df)
plt.title("Cholesterol Levels by Chest Pain Type and Target")
plt.xlabel("Chest Pain Type")
plt.ylabel("Cholesterol")
plt.show()

# %% [markdown]
# # Distribution of Blood Pressure (trestbps) by Target

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x="trestbps", hue="target", kde=True, bins=15)
plt.title("Blood Pressure Distribution by Target")
plt.xlabel("Resting Blood Pressure (trestbps)")
plt.ylabel("Frequency")
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# # Count Plot for Chest Pain Type (cp) by Target

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='cp', hue='target', data=df)
plt.title("Chest Pain Type (cp) Count by Target")
plt.xlabel("Chest Pain Type (cp)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Split the data into features and target

# %%
X = df.drop('target', axis=1)
y = df['target']

# %% [markdown]
# # Split the data into training and test sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# # Initialize and train the logistic regression model

# %%
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# # Make predictions

# %%
y_pred = model.predict(X_test)
y_prob = model.predict_proba(X_test)[:, 1]

# %% [markdown]
# # Evaluation Metrics

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("ROC AUC Score:", roc_auc_score(y_test, y_prob))
# Out:
# Accuracy: 0.8131868131868132
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.78      0.79        41
#            1       0.82      0.84      0.83        50
#
#     accuracy                           0.81        91
#    macro avg       0.81      0.81      0.81        91
# weighted avg       0.81      0.81      0.81        91
#
# Confusion Matrix:
#  [[32  9]
#  [ 8 42]]
# ROC AUC Score: 0.8814634146341463

# %% [markdown]
# # Confusion Matrix Visualization

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# # ROC Curve

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, roc_curve, accuracy_score

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='orange', label="ROC Curve (AUC = {:.2f})".format(roc_auc_score(y_test, y_prob)))
plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# %% [markdown]
# # Feature Distribution by Target

# %%
for column in X.columns:
    plt.figure(figsize=(8, 6))
    sns.histplot(data=df, x=column, hue="target", kde=True, multiple="stack")
    plt.title(f"Distribution of {column} by Target")
    plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...
